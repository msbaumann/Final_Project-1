# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading the data into a variable
data = pd.read_excel('journal.pone.0112102.s005.XLSX')

# %%
#peeking at the data
data.head(5)
# Out:
#       test_id     gene_id        gene                    locus sample_1  \
# 0      21ur-1      21ur-1      21ur-1  chrIV:16687073-16687098      ref
# 1     21ur-10     21ur-10     21ur-10  chrIV:16888163-16888184      ref
# 2    21ur-100    21ur-100    21ur-100    chrIV:5924786-5924807      ref
# 3   21ur-1000   21ur-1000   21ur-1000  chrIV:14721532-14721553      ref
# 4  21ur-10000  21ur-10000  21ur-10000  chrIV:17151519-17151540      ref
#
#   sample_2  status  value_1  value_2  log2(fold_change)  test_stat  p_value  \
# 0      NSM  NOTEST        0        0                  0          0        1
# 1      NSM  NOTEST        0        0                  0          0        1
# 2      NSM  NOTEST        0        0                  0          0        1
# 3      NSM  NOTEST        0        0                  0          0        1
# 4      NSM  NOTEST        0        0                  0          0        1
#
#    q_value significant
# 0        1          no
# 1        1          no
# ...

# %% [markdown]
# # Munging the data by the expressed gene

# %%
# When looking through your data there are a lot of values, especially in the first part, that are 0 and dont
# seem to show any useful information. 
# Maybe you could first get rid of all of these rows so you can compare genes that actually gave you values.

# Also, the significant column is very interesting. Maybe you could delete all rows that are not significant.
# If you want to do this, you can use (and make the table a new variable): 

# filename.groupby(['Name of Column]).get_group('String').   SO:

significant_data = data.groupby(['significant']).get_group('yes')
significant_data.head()
# Out:
#       test_id gene_id    gene                   locus sample_1 sample_2  \
# 13354  aagr-2  aagr-2  aagr-2   chrII:4914602-4925238      ref      NSM
# 13358   aak-2   aak-2   aak-2  chrX:16796015-16802777      ref      NSM
# 13372   aat-4   aat-4   aat-4   chrIV:6272732-6275702      ref      NSM
# 13383  abcx-1  abcx-1  abcx-1   chrII:6532145-6535333      ref      NSM
# 13394   abt-4   abt-4   abt-4      chrV:323910-330725      ref      NSM
#
#       status     value_1    value_2  log2(fold_change)  test_stat  p_value  \
# 13354     OK   67.903000    7.27032          -3.223380   -3.26985  0.00010
# 13358     OK  134.403000  608.79000           2.179380    2.86278  0.00015
# 13372     OK    0.221390    0.00000               -inf        NaN  0.00640
# 13383     OK    0.394415    0.00000               -inf        NaN  0.00005
# 13394     OK   12.175900  244.27600           4.326410    5.31215  0.00005
#
#         q_value significant
# 13354  0.000972         yes
# ...

# %%
# Now to group your data by expressed gene you could, 
# first set the gene column as the index:

gene_ind = significant_data.set_index('gene')
gene_ind
# Out:
#            test_id   gene_id                    locus sample_1 sample_2  \
# gene
# aagr-2      aagr-2    aagr-2    chrII:4914602-4925238      ref      NSM
# aak-2        aak-2     aak-2   chrX:16796015-16802777      ref      NSM
# aat-4        aat-4     aat-4    chrIV:6272732-6275702      ref      NSM
# abcx-1      abcx-1    abcx-1    chrII:6532145-6535333      ref      NSM
# abt-4        abt-4     abt-4       chrV:323910-330725      ref      NSM
# abts-4      abts-4    abts-4     chrX:6747591-6761657      ref      NSM
# abu-12      abu-12    abu-12       chrX:450650-457418      ref      NSM
# abu-8        abu-8     abu-8     chrV:5193122-5194551      ref      NSM
# acc-3        acc-3     acc-3     chrX:4722980-4726821      ref      NSM
# acd-1        acd-1     acd-1     chrI:4103714-4107969      ref      NSM
# acd-2        acd-2     acd-2     chrI:4094611-4098112      ref      NSM
# acd-3        acd-3     acd-3   chrX:14849269-14852473      ref      NSM
# ...

# %%
data.groupby(['gene']).get_group('21ur')

# %%
#grouping data
grouped_data = data.groupby('gene')

# %%
#peeking again
grouped_data
